# %%
# list
# define empty list
a_list = []
# append new item into list at the end of the list
a_list.append(new_item)
# append new item into list at a specific index
a_list.insert(index, new_item)
# remove an item from the list based on index
a_list.pop(0)
# remove an item from the list based on item value
a_list.remove('two')
# sort the items in ascending order, note that the data types must be similar
a_list.sort()
# reverse the order of the items
a_list.reverse()

# set 
# define an empty set
a_set = set()
# define a set
a_set = {'one', 2}
# adding item to a set
a_set.add('c')
# removing an item from a set, raise keyError if item does not exist
a_set.remove('one')
# removing an item from a set, no keyError if item does not exist
a_set.discard('one')
# remove the first item from a set and return it
a_set.pop()
# remove all items from a set
a_set.clear()

# Dictionary
# define an empty dictionary
a_dict = {}
# define a dictionary
a_dict = {"one":1, "two":2}
# adding new items to the dictionary
a_dict[new_key] = new_value
# removing items from the dictionary
del a_dict[a_key]
# display the keys in the dictionary
a_dict.keys()
# display the values in the dictionary
a_dict.values()
# display the items in the dictionary
a_dict.items()

# %%
# Conversion
# List to Set Conversion
def list_to_set(int_list):
    my_set = set()
    for each in int_list:
        my_set.add(each)
    
    return my_set

# List to Dictionary Conversion
def list_to_dict(key_list, value_list):
    my_dict = {}
    for i in range (0, len(key_list)):
        my_dict[key_list[i]] = value_list[i]
        
    return my_dict

# Set to Dictionary Conversion
def set_to_dict(tuple_set):
    my_dict = {}
    for each in tuple_set:
        my_dict[each[0]] = each[1]
    
    return my_dict

# %%
# Tkinter important
from tkinter import *
from tkinter import messagebox
mybox = Tk()
mybox.geometry('500x400')
mybox.title('This is a box')
mybox.config(bg='Blue')
# 🔴Button
mybtn = Button(mybox,text='Button',bg='RED',fg='Yellow').pack(side='left')
# 🔴Canva 
myc = Canvas(mybox,width=200,height=200,bg='yellow')
myarc = myc.create_arc(10,10,150,110,start=0,extent=300,fill='red',outline='green',width=10)
myc.place(relx=.1,rely=.1)
# 🔴CheckButton 
checkvar1 = IntVar()  
checkvar2 = IntVar()  
checkvar3 = IntVar()  
chkbtn1 = Checkbutton(mybox, text = "C", variable = checkvar1, onvalue = 1, offvalue = 0, height = 2, width = 10)  
chkbtn2 = Checkbutton(mybox, text = "C++", variable = checkvar2, onvalue = 1, offvalue = 0, height = 2, width = 10)  
chkbtn3 = Checkbutton(mybox, text = "Java", variable = checkvar3, onvalue = 1, offvalue = 0, height = 2, width = 10)  
chkbtn1.pack()  
chkbtn2.pack()  
chkbtn3.pack()  
# 🔴Entry 
name = Label(mybox, text = "Name").place(x = 30,y = 50)  
email = Label(mybox, text = "Email").place(x = 30, y = 90)  
password = Label(mybox, text = "Password").place(x = 30, y = 130)  
sbmitbtn = Button(mybox, text = "Submit",activebackground = "pink", activeforeground = "blue").place(x = 30, y = 170)  
e1 = Entry(mybox).place(x = 80, y = 50)  
e2 = Entry(mybox).place(x = 80, y = 90)  
e3 = Entry(mybox).place(x = 95, y = 130)  
# 🔴Frame - Python Tkinter Frame widget is used to organize the group of widgets. It acts like a container which can be used to hold the other widgets. The rectangular areas of the screen are used to organize the widgets to the python application.
frame = Frame(mybox)  
frame.pack()  
leftframe = Frame(mybox)  
leftframe.pack(side = LEFT)  
rightframe = Frame(mybox)  
rightframe.pack(side = RIGHT)  
btn1 = Button(frame, text="Submit", fg="red",activebackground = "red")  
btn1.pack(side = LEFT)  
btn2 = Button(frame, text="Remove", fg="brown", activebackground = "brown")  
btn2.pack(side = RIGHT)  
btn3 = Button(rightframe, text="Add", fg="blue", activebackground = "blue")  
btn3.pack(side = LEFT)  
btn4 = Button(leftframe, text="Modify", fg="black", activebackground = "white")  
btn4.pack(side = RIGHT)  
# 🔴Label - The Label is used to specify the container box where we can place the text or images. This widget is used to provide the message to the user about other widgets used in the python application.
#creating label  
uname = Label(mybox, text = "Username").place(x = 30,y = 50)  
  
#creating label  
password = Label(mybox, text = "Password").place(x = 30, y = 90)  
  
  
sbmitbtn = Button(mybox, text = "Submit",activebackground = "pink", activeforeground = "blue").place(x = 30, y = 120)  
  
e1 = Entry(mybox,width = 20).place(x = 100, y = 50)  
  
  
e2 = Entry(mybox, width = 20).place(x = 100, y = 90)  
# 🔴ListBox 
lbl = Label(mybox,text = "A list of favourite countries...")  
  
listbox = Listbox(mybox)  
  
listbox.insert(1,"India")  
  
listbox.insert(2, "USA")  
  
listbox.insert(3, "Japan")  
  
listbox.insert(4, "Austrelia")  
  
lbl.pack()  
listbox.pack()  
# 🔴Menubutton 
menubutton = Menubutton(mybox, text = "Language", relief = FLAT)  
  
menubutton.grid()  
  
menubutton.menu = Menu(menubutton)  
  
menubutton["menu"]=menubutton.menu  
  
menubutton.menu.add_checkbutton(label = "Hindi", variable=IntVar())  
  
menubutton.menu.add_checkbutton(label = "English", variable = IntVar())  
  
menubutton.pack()  
# 🔴Menu - The Menu widget is used to create various types of menus (mybox level, pull down, and pop up) in the python application.
def hello():  
    print("hello!")  
# create a myboxlevel menu  
menubar = Menu(mybox)  
menubar.add_command(label="Hello!", command=hello)  
menubar.add_command(label="Quit!", command=mybox.quit)  
# display the menu  
mybox.config(menu=menubar)  

# 🔴Message 
var = StringVar()  
msg = Message( mybox, text = "Welcome to Javatpoint")  
msg.pack()  
# 🔴Radiobutton 
def selection():  
   selection = "You selected the option " + str(radio.get())  
   label.config(text = selection)  
radio = IntVar()  
lbl = Label(text = "Favourite programming language:")  
lbl.pack()  
R1 = Radiobutton(mybox, text="C", variable=radio, value=1,  
                  command=selection)  
R1.pack( anchor = W )  
  
R2 = Radiobutton(mybox, text="C++", variable=radio, value=2,  
                  command=selection)  
R2.pack( anchor = W )  
  
R3 = Radiobutton(mybox, text="Java", variable=radio, value=3,  
                  command=selection)  
R3.pack( anchor = W)  
  
label = Label(mybox)  
label.pack()  
# 🔴Scale 
def select():  
   sel = "Value = " + str(v.get())  
   label.config(text = sel)  
v = DoubleVar()  
scale = Scale( mybox, variable = v, from_ = 1, to = 50, orient = HORIZONTAL)  
scale.pack(anchor=CENTER)  
  
btn = Button(mybox, text="Value", command=select)  
btn.pack(anchor=CENTER)  
  
label = Label(mybox)  
label.pack()  
# 🔴Scrollbar 
sb = Scrollbar(mybox)  
sb.pack(side = RIGHT, fill = Y)  
  
mylist = Listbox(mybox, yscrollcommand = sb.set )  
  
for line in range(30):  
    mylist.insert(END, "Number " + str(line))  
  
mylist.pack( side = LEFT )  
sb.config( command = mylist.yview )  
# 🔴text 
text = Text(mybox)  
text.insert(INSERT, "Name.....")  
text.insert(END, "Salary.....")  
  
text.pack()  
  
text.tag_add("Write Here", "1.0", "1.4")  
text.tag_add("Click Here", "1.8", "1.13")  
  
text.tag_config("Write Here", background="yellow", foreground="black")  
text.tag_config("Click Here", background="black", foreground="white")  
# 🔴myboxlevel Not found
# 🔴spinbox 
spin = Spinbox(mybox, from_= 0, to = 25)  
  
spin.pack()  
# 🔴PanedWindow 
def add():  
    a = int(e1.get())  
    b = int(e2.get())  
    leftdata = str(a+b)  
    left.insert(1,leftdata)  
  
w1 = PanedWindow()  
w1.pack(fill = BOTH, expand = 1)  
  
left = Entry(w1, bd = 5)  
w1.add(left)  
  
w2 = PanedWindow(w1, orient = VERTICAL)  
w1.add(w2)  
  
e1 = Entry(w2)  
e2 = Entry(w2)  
  
w2.add(e1)  
w2.add(e2)  
  
bottom = Button(w2, text = "Add", command = add)  
w2.add(bottom)  
# 🔴LabelFrame 
labelframe1 = LabelFrame(mybox, text="Positive Comments")  
labelframe1.pack(fill="both", expand="yes")  
  
myboxlabel = Label(labelframe1, text="Place to put the positive comments")  
myboxlabel.pack()  
  
labelframe2 = LabelFrame(mybox, text = "Negative Comments")  
labelframe2.pack(fill="both", expand = "yes")  
  
bottomlabel = Label(labelframe2,text = "Place to put the negative comments")  
bottomlabel.pack()  
# 🔴tkMessageBox 
messagebox.showinfo("information","Information")  
messagebox.showwarning("warning","Warning")  
messagebox.showerror("error","Error")  
mainloop()
